# %% [markdown]
# <a href="https://colab.research.google.com/github/AliTabatabaiGWU/HW2_Test_SEAS8515/blob/main/HW_2_DeepLearning_FAshionMNIST_Tabatabai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# load and process data

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import fashion_mnist
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Load the dataset

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# Normalize pixel values to be between 0.0 and 1.0 by dividing by 255

X_train = X_train / 255.0
X_test = X_test / 255.0

# Define the class names for plotting

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

print(f"Training data shape: {X_train.shape}")
print(f"Test data shape: {X_test.shape}")


# Architecture 1 shallow

print("--- Training Model 1 ---")

# Build Model 1

model_1 = models.Sequential([
    layers.Flatten(input_shape=(28, 28)), # Flattens 2D images to 784 vectors
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax') # 10 classes outputting a probability distribution
])

# Compile using sparse categorical crossentropy so we don't have to one-hot encode labels

model_1.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

# Print total parameter count

model_1.summary()

# Train the model

history_1 = model_1.fit(X_train, y_train,
                        epochs=10,
                        validation_split=0.2, # Holds out 20% of training data for validation
                        batch_size=64)

# Evaluate on the test set

test_loss_1, test_acc_1 = model_1.evaluate(X_test, y_test, verbose=0)
print(f"\nModel 1 Final Test Accuracy: {test_acc_1:.4f}")

# Architecture 2 - Deeper with Regularization

print("--- Training Model 2 ---")

# Build Model 2

model_2 = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(256, activation='relu'),   # Increased width
    layers.Dropout(0.3),                    # Regularization step to prevent memorizing noise
    layers.Dense(128, activation='relu'),   # Increased depth
    layers.Dense(10, activation='softmax')
])

model_2.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

# Print total parameter count

model_2.summary()

# Train the model
history_2 = model_2.fit(X_train, y_train,
                        epochs=10,
                        validation_split=0.2,
                        batch_size=64)

# Evaluate on the test set

test_loss_2, test_acc_2 = model_2.evaluate(X_test, y_test, verbose=0)
print(f"\nModel 2 Final Test Accuracy: {test_acc_2:.4f}")

# Plot learning curves

# Note to self: Change this to history=1 if Model 1 performed better

best_history = history_2

epochs_range = range(1, 11)

plt.figure(figsize=(14, 5))

# Plot 1: Accuracy Curves

plt.subplot(1, 2, 1)
plt.plot(epochs_range, best_history.history['accuracy'], label='Training Accuracy')
plt.plot(epochs_range, best_history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs. Validation Accuracy')
plt.legend()

# Plot 2: Loss Curves

plt.subplot(1, 2, 2)
plt.plot(epochs_range, best_history.history['loss'], label='Training Loss')
plt.plot(epochs_range, best_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs. Validation Loss')
plt.legend()

# Save the plot automatically to my Colab directory

plt.savefig('best_model_learning_curves.png')
plt.show()

# confusion matrix heatmap

# note to self:  Change this to model_1 if Model 1 is a better performer
best_model = model_2

# Generate predictions (probabilities)

y_pred_probs = best_model.predict(X_test)

# Get the index of the highest probability for each sample

y_pred = np.argmax(y_pred_probs, axis=1)

# Create the confusion matrix

cm = confusion_matrix(y_test, y_pred) #[cite: 122]

# Plot using Seaborn

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.ylabel('Actual Class')
plt.xlabel('Predicted Class')
plt.title('Confusion Matrix - Best Model')
plt.show()
# Out:
# Training data shape: (60000, 28, 28)
# Test data shape: (10000, 28, 28)
# --- Training Model 1 ---
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_2 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,770 (397.54 KB)
#  Trainable params: 101,770 (397.54 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# ...

# %%
# Plot learning curves

# Note to self: Change this to history=2 if Model 2 performed better

best_history = history_1

epochs_range = range(1, 11)

plt.figure(figsize=(14, 5))

# Plot 1: Accuracy Curves

plt.subplot(1, 2, 1)
plt.plot(epochs_range, best_history.history['accuracy'], label='Training Accuracy')
plt.plot(epochs_range, best_history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs. Validation Accuracy')
plt.legend()

# Plot 2: Loss Curves

plt.subplot(1, 2, 2)
plt.plot(epochs_range, best_history.history['loss'], label='Training Loss')
plt.plot(epochs_range, best_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs. Validation Loss')
plt.legend()

# Save the plot automatically to my Colab directory

plt.savefig('best_model_learning_curves2.png')
plt.show()

# confusion matrix heatmap

# note to self:  Change this to model_2 if Model 2 is a better performer
best_model = model_1

# Generate predictions (probabilities)

y_pred_probs = best_model.predict(X_test)

# Get the index of the highest probability for each sample

y_pred = np.argmax(y_pred_probs, axis=1)

# Create the confusion matrix

cm = confusion_matrix(y_test, y_pred) #[cite: 122]

# Plot using Seaborn

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.ylabel('Actual Class')
plt.xlabel('Predicted Class')
plt.title('Confusion Matrix - Best Model')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
